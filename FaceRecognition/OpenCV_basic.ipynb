# %%
import matplotlib.pyplot as plt
import cv2

# %%
img=cv2.imread("wallpaperflare.com_wallpaper (1).jpg")
print(img)
# Out:
# [[[34 16 17]
#   [35 14 16]
#   [47 23 25]
#   ...
#   [80 30 32]
#   [81 31 33]
#   [80 29 33]]
#
#  [[34 16 17]
#   [36 14 16]
#   [44 20 22]
#   ...
#   [80 30 32]
#   [80 30 32]
#   [80 30 32]]
#
#  [[34 16 17]
#   [35 14 16]
#   [39 17 19]
#   ...
#   [80 30 32]
#   [80 30 32]
#   [80 30 32]]
#
#  ...
#
#  [[32 14 15]
#   [32 14 15]
#   [32 14 15]
#   ...
#   [32 14 15]
#   [32 14 15]
#   [32 14 15]]
#
#  [[32 14 15]
#   [32 14 15]
#   [32 14 15]
#   ...
#   [32 14 15]
#   [32 14 15]
#   [32 14 15]]
#
#  [[32 14 15]
#   [32 14 15]
#   [32 14 15]
#   ...
#   [32 14 15]
#   [32 14 15]
#   [32 14 15]]]

# %%
print(img.shape)
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img)

# %%
newImg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(newImg)

# %%
cam=cv2.VideoCapture(0)

while True:
    sucess,img2=cam.read()

    if not sucess:
        print("Image could not read")
    else:
        cv2.imshow("image",img2)
        cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 cam=cv2.VideoCapture(0)
#       3 while True:
# ----> 4     sucess,img2=cam.read()
#       6     if not sucess:
#       7         print("Image could not read")
#
# KeyboardInterrupt:
